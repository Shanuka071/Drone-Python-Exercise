# %%
import pysimverse
import cv2 # This is OpenCV
import zmq # This is PyZMQ
import time

print("Environment Setup  Successful!")
# Out:
# Environment Setup Successful!

# %%
from pysimverse import Drone
drone=Drone()
drone.connect()
# Out:
# ---------------------------------------------------------------------------
# ZMQError                                  Traceback (most recent call last)
# Cell In[2], line 3
#       1 from pysimverse import Drone
#       2 drone=Drone()
# ----> 3 drone.connect()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pysimverse\simulators\drone\drone.py:51, in Drone.connect(self)
#      44 """
#      45 Set up ZeroMQ with three distinct ports:
#      46 - Command port for sending commands.
#      47 - State port for receiving telemetry/state data.
#      48 - Video port for receiving video data or other additional subscriptions.
#      49 """
#      50 # Command Publisher setup
# ---> 51 self.command_socket.bind(self.command_address)
#      53 self.state_socket.connect(self.state_address)
#      54 self.state_socket.setsockopt_string(zmq.SUBSCRIBE, "")  # Subscribe to all telemetry/state messages
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\zmq\sugar\socket.py:320, in Socket.bind(self, addr)
#     292 """s.bind(addr)
#     293
#     294 Bind the socket to an address.
#    (...)    317
#     318 """
#     319 try:
# --> 320     super().bind(addr)
#     321 except ZMQError as e:
#     322     e.strerror += f" (addr={addr!r})"
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\zmq\backend\cython\_zmq.py:1009, in zmq.backend.cython._zmq.Socket.bind()
#    1007 while True:
#    1008     try:
# -> 1009         _check_rc(rc)
#    1010     except InterruptedSystemCall:
#    1011         rc = zmq_bind(self.handle, c_addr)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\zmq\backend\cython\_zmq.py:190, in zmq.backend.cython._zmq._check_rc()
#     188         raise ContextTerminated(errno)
#     189     else:
# --> 190         raise ZMQError(errno)
#     191 return 0
#
# ZMQError: Address in use (addr='tcp://*:5550')
