# %%
import pysimverse
import cv2 # This is OpenCV
import zmq # This is PyZMQ
import time

# %%
from pysimverse import Drone 
drone=Drone()   
drone.connect()
# Out:
# Response: Connected

# %%
drone.take_off()
drone.move_left(250)
drone.move_forward(450)
# Out:
# Published RC control data: {'left_right': 0, 'forward_backward': 0, 'up_down': 25, 'yaw': 0, 'cameraangle': 0, 'streamon': None, 'color': {'red': None, 'green': None, 'blue': None}}
# Published RC control data: {'left_right': 0, 'forward_backward': 0, 'up_down': 0, 'yaw': 0, 'cameraangle': 0, 'streamon': None, 'color': {'red': None, 'green': None, 'blue': None}}
# Drone has taken off.
# Published RC control data: {'left_right': -20, 'forward_backward': 0, 'up_down': 0, 'yaw': 0, 'cameraangle': 0, 'streamon': None, 'color': {'red': None, 'green': None, 'blue': None}}
# Published RC control data: {'left_right': 0, 'forward_backward': 0, 'up_down': 0, 'yaw': 0, 'cameraangle': 0, 'streamon': None, 'color': {'red': None, 'green': None, 'blue': None}}
# Published RC control data: {'left_right': 0, 'forward_backward': 20, 'up_down': 0, 'yaw': 0, 'cameraangle': 0, 'streamon': None, 'color': {'red': None, 'green': None, 'blue': None}}
# ...

# %%
drone.move_backward(150)
drone.move_right(250)
# Out:
# Published RC control data: {'left_right': 0, 'forward_backward': -20, 'up_down': 0, 'yaw': 0, 'cameraangle': 0, 'streamon': None, 'color': {'red': None, 'green': None, 'blue': None}}
# Published RC control data: {'left_right': 0, 'forward_backward': 0, 'up_down': 0, 'yaw': 0, 'cameraangle': 0, 'streamon': None, 'color': {'red': None, 'green': None, 'blue': None}}
# Published RC control data: {'left_right': 20, 'forward_backward': 0, 'up_down': 0, 'yaw': 0, 'cameraangle': 0, 'streamon': None, 'color': {'red': None, 'green': None, 'blue': None}}
# Published RC control data: {'left_right': 0, 'forward_backward': 0, 'up_down': 0, 'yaw': 0, 'cameraangle': 0, 'streamon': None, 'color': {'red': None, 'green': None, 'blue': None}}

# %%
drone.move_up(100)
time.sleep(2)
drone.move_down(50) # Now it has room to move
# Out:
# Published RC control data: {'left_right': 0, 'forward_backward': 0, 'up_down': 20, 'yaw': 0, 'cameraangle': 0, 'streamon': None, 'color': {'red': None, 'green': None, 'blue': None}}
# Published RC control data: {'left_right': 0, 'forward_backward': 0, 'up_down': 0, 'yaw': 0, 'cameraangle': 0, 'streamon': None, 'color': {'red': None, 'green': None, 'blue': None}}
# Published RC control data: {'left_right': 0, 'forward_backward': 0, 'up_down': -20, 'yaw': 0, 'cameraangle': 0, 'streamon': None, 'color': {'red': None, 'green': None, 'blue': None}}
# Published RC control data: {'left_right': 0, 'forward_backward': 0, 'up_down': 0, 'yaw': 0, 'cameraangle': 0, 'streamon': None, 'color': {'red': None, 'green': None, 'blue': None}}

# %%
drone.move_right(50)
# Out:
# Published RC control data: {'left_right': 20, 'forward_backward': 0, 'up_down': 0, 'yaw': 0, 'cameraangle': 0, 'streamon': None, 'color': {'red': None, 'green': None, 'blue': None}}
# Published RC control data: {'left_right': 0, 'forward_backward': 0, 'up_down': 0, 'yaw': 0, 'cameraangle': 0, 'streamon': None, 'color': {'red': None, 'green': None, 'blue': None}}

# %%
drone.move_up(20)
# Out:
# Published RC control data: {'left_right': 0, 'forward_backward': 0, 'up_down': 20, 'yaw': 0, 'cameraangle': 0, 'streamon': None, 'color': {'red': None, 'green': None, 'blue': None}}
# Published RC control data: {'left_right': 0, 'forward_backward': 0, 'up_down': 0, 'yaw': 0, 'cameraangle': 0, 'streamon': None, 'color': {'red': None, 'green': None, 'blue': None}}

# %%
drone.move_down(40)
# Out:
# Published RC control data: {'left_right': 0, 'forward_backward': 0, 'up_down': -20, 'yaw': 0, 'cameraangle': 0, 'streamon': None, 'color': {'red': None, 'green': None, 'blue': None}}
# Published RC control data: {'left_right': 0, 'forward_backward': 0, 'up_down': 0, 'yaw': 0, 'cameraangle': 0, 'streamon': None, 'color': {'red': None, 'green': None, 'blue': None}}

# %%
drone.move_right(100)
# Out:
# Published RC control data: {'left_right': 20, 'forward_backward': 0, 'up_down': 0, 'yaw': 0, 'cameraangle': 0, 'streamon': None, 'color': {'red': None, 'green': None, 'blue': None}}
# Published RC control data: {'left_right': 0, 'forward_backward': 0, 'up_down': 0, 'yaw': 0, 'cameraangle': 0, 'streamon': None, 'color': {'red': None, 'green': None, 'blue': None}}

# %%
drone.move_down(100)
# Out:
# Published RC control data: {'left_right': 0, 'forward_backward': 0, 'up_down': -20, 'yaw': 0, 'cameraangle': 0, 'streamon': None, 'color': {'red': None, 'green': None, 'blue': None}}
# Published RC control data: {'left_right': 0, 'forward_backward': 0, 'up_down': 0, 'yaw': 0, 'cameraangle': 0, 'streamon': None, 'color': {'red': None, 'green': None, 'blue': None}}

# %%
drone.land()
# Out:
# Published RC control data: {'left_right': 0, 'forward_backward': 0, 'up_down': -25, 'yaw': 0, 'cameraangle': 0, 'streamon': None, 'color': {'red': None, 'green': None, 'blue': None}}
# Published RC control data: {'left_right': 0, 'forward_backward': 0, 'up_down': 0, 'yaw': 0, 'cameraangle': 0, 'streamon': None, 'color': {'red': None, 'green': None, 'blue': None}}
# Drone has landed.

# %%
drone.take_off(20)
# Out:
# Published RC control data: {'left_right': 0, 'forward_backward': 0, 'up_down': 25, 'yaw': 0, 'cameraangle': 0, 'streamon': None, 'color': {'red': None, 'green': None, 'blue': None}}
# Published RC control data: {'left_right': 0, 'forward_backward': 0, 'up_down': 0, 'yaw': 0, 'cameraangle': 0, 'streamon': None, 'color': {'red': None, 'green': None, 'blue': None}}
# Drone has taken off.

# %%
drone.move_backward(50)
# Out:
# Published RC control data: {'left_right': 0, 'forward_backward': -20, 'up_down': 0, 'yaw': 0, 'cameraangle': 0, 'streamon': None, 'color': {'red': None, 'green': None, 'blue': None}}
# Published RC control data: {'left_right': 0, 'forward_backward': 0, 'up_down': 0, 'yaw': 0, 'cameraangle': 0, 'streamon': None, 'color': {'red': None, 'green': None, 'blue': None}}

# %%
drone.move_right(70)
# Out:
# Published RC control data: {'left_right': 20, 'forward_backward': 0, 'up_down': 0, 'yaw': 0, 'cameraangle': 0, 'streamon': None, 'color': {'red': None, 'green': None, 'blue': None}}
# Published RC control data: {'left_right': 0, 'forward_backward': 0, 'up_down': 0, 'yaw': 0, 'cameraangle': 0, 'streamon': None, 'color': {'red': None, 'green': None, 'blue': None}}
